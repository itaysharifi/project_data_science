# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from spacy.lang.en import English
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt
import math
from pprint import pprint
from time import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import plot_confusion_matrix

# %%
def get_histogram_per_all_classes(data):
    categories = list(data.keys())
    values = list(data.values())

    fig = plt.figure(figsize=(10, 5))

    # creating the bar plot
    plt.bar(categories, values, color='lightblue',
            width=0.4)

    plt.xlabel("Title's Category")
    plt.ylabel("Number of titles")
    plt.title("Number of titles - 1fin 2ent")
    plt.show()

# %%
def is_hebrew(text):
    print(text)
    if isinstance(text, float) and math.isnan(text):
        return True

    is_heb = any("\u0590" <= c <= "\u05EA" for c in text)
    return is_heb

# %%
def is_irrelevant(text):
    black_list_strings = ["Trending Now", 'Weather', 'Ad']
    return text in black_list_strings

# %%
parameters = {
    "vect__max_df": (0.5, 0.75, 1.0),
    "vect__ngram_range": ((1, 1), (1, 2)),  # unigrams or bigrams
    "clf__max_iter": (20,),
    "clf__penalty": ("l2", "elasticnet"),
}

# %%
if __name__ == '__main__':

    mapping_result = {
        1: "Finance",
        2: "Entertainment"
    }

    df_finance = pd.read_csv(
        'yahoo_data_selenium_finance.csv',
        #delimiter='\t',
        index_col=['text'])
    #print (df_finance)

    labels_finance = [1] * df_finance.shape[0]
    df_finance['label'] = labels_finance

    df_entertainment = pd.read_csv(
        'yahoo_data_selenium_ent.csv',
        #delimiter='\t',
        index_col=['text'])

    labels_entertainment = [2] * df_entertainment.shape[0]
    df_entertainment['label'] = labels_entertainment

    df_all = pd.concat([df_finance, df_entertainment])
    df_all.reset_index(inplace=True)
    df_all = df_all.loc[:, ['text', 'label']]
    # df = pd.read_csv('../yahoo_scraper/yahoo_data.csv')

    df_all['is_hebrew'] = df_all['text'].apply(lambda x: is_hebrew(x))
    df_all['is_ads'] = df_all['text'].apply(lambda x: is_irrelevant(x))
    df_all = df_all.loc[df_all.is_hebrew == False]
    df_all = df_all.loc[df_all.is_ads == False]
    df_all.to_csv('yahoo_data_2_categories_clean.csv', index=False)
    my_hist = dict(df_all['label'].value_counts())
    print(my_hist)

    parser = English()

    print(f"Dataframe holds {df_all.shape[0]} rows.")
    get_histogram_per_all_classes(my_hist)
    # label_encoder = LabelEncoder()
    # df_all['label'] = label_encoder.fit_transform(df_all['label'])

    df_all = df_all.sample(frac=1.0)
    df_all.reset_index(inplace=True)
    df_all = df_all.loc[:, ['text', 'label']]

    X = df_all['text']
    y = df_all['label']

    # spliting our data into train set and test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    print(f"X_train: {X_train.shape[0]}")
    print(f"X_test: {X_test.shape[0]}")

    # tfidf_vector = TfidfVectorizer(tokenizer=spacy_tokenizer)
    # classifier = svm.SVC(kernel='linear')

    pipe = Pipeline(
        [
            ('vect', CountVectorizer()),
            ("tfidf", TfidfTransformer()),
            ('clf', LogisticRegression()),
        ]
    )

    # print("pipeline:", [name for name, _ in pipe.steps])

    grid_search = GridSearchCV(pipe, parameters, n_jobs=-1, verbose=1)

    # pipe.fit_transform(X=X_train, y=y_train)
    # predictions = pipe.predict(X_test)
    #
    # accuracy_model_score = accuracy_score(y_true=y_test,
    #                                       y_pred=predictions)

    print("Performing grid search...")
    # print("pipeline:", [name for name, _ in pipe.steps])
    print("parameters:")
    pprint(parameters)
    t0 = time()

    grid_search.fit(X_train, y_train)
    print("done in %0.3fs" % (time() - t0))
    print()

    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))

    # X_test = data_test_sentences
    predictions = grid_search.predict(X_test)
    for sentence, predict in zip(X_test, predictions):
        print("For Sentence: ", sentence, "prediction was: ", mapping_result[predict])

    print("grid_search.predict(Which is the fastest bike?): ", grid_search.predict(['Which is the fastest bike?']))

    print("The accuracy of model on test set is:", accuracy_score(y_true=y_test,
                                                                  y_pred=predictions))

    plot_confusion_matrix(grid_search.best_estimator_, X_test, y_test)
    plt.show()
    print("The Precision:", precision_score(y_true=y_test, y_pred=predictions))
    print("The Recall:", recall_score(y_true=y_test, y_pred=predictions))

    print("tgbfg")
# Out:
# nan
# nan
# S&P Futures
# 3,778.75
# -42.50(-1.11%)
# Dow Futures
# 30,682.00
# -317.00(-1.02%)
# Nasdaq Futures
# 11,552.00
# -139.00(-1.19%)
# Russell 2000 Futures
# 1,697.70
# -23.70(-1.38%)
# Crude Oil
# 108.68
# -1.10(-1.00%)
# nan
# Futures fall, S&P 500 heads for worst first half in 52 years
# Strategist: Recession 'barely beginning to be priced in'
# The bitter battle for Spirit Airlines takes another odd turn
# Global response to climate will 'change the world over the next 75 years': Costis Maglaras
# Influencers with Andy Serwer: Costis Maglaras
# Why this round of tech layoffs feels different
# Bed Bath & Beyond is 'in the end days,' analyst says
# Big Food shakeup ‘already underway’ amid Kellogg's split
# Tech stocks are having their worst year ever. Here's what history says happens next: Morning Brief
# The Most Expensive Divorce Settlements of All-Time
# 60-Year Wall Street Veteran Says S&P 500 Will Sink to 3,100
# Chip Stocks Are in for Trouble, Analyst Says. 4 Stocks Get Downgrades.
# Here’s how much your Social Security check is likely to go up next year
# ‘This recession will be the most severe yet’: Peter Schiff called the 2008 financial crash and now says the next downturn will be worse. Here's what he likes for safety
# China Just Bought These Major US Companies
# Should I wait for real estate prices to crash before I buy a house? Here are 3 simple reasons why this housing downturn is nothing like 2008
# How can I 'quiet' my portfolio? Here are 3 top dividend stocks for stable cash return and inflation protection — one of them even offers an incredible 14.9% yield
# Germany seizes three Gazprom tankers in new blow for Putin - live updates
# Sell Exxon Mobil and other energy stocks before these headwinds hit prices once again
# These Maps Will Change Your View Of The World
# Stock Futures Drop Ahead of Fed’s Favored Inflation Gauge
# Dow Jones Dives As Inflation Fears Rise; This Stock Pops As Warren Buffett Raises Stake; Nike Plunges
# RBC Says These 2 Dividend Stocks Have Strong Growth Potential
# New report reveals major source of recent crypto market chaos
# 12 Foods You Can Eat a Lot of Without Getting Fat
# Bitcoin fights to stay above $20,000 as Saylor buys another $10 million worth
# Apple TV+ Might Have the Next ‘Big Little Lies’ on its Hands With ‘Surface’
# The Truth About Johnny Depp's Rumored $300 Million Pirates of the Caribbean Return
# Emma Roberts Cast in Sony’s Star-Studded Marvel Movie ‘Madame Web’
# Ben Affleck's 10-year-old son reverses pricey Lamborghini into parked BMW
# ‘The View’ Co-Host Sunny Hostin Doesn’t Believe in Abortion or ‘Any Exception,’ Even Incest, but Disagrees With Supreme Court
# Vanessa Hudgens Visits the Iconic School Featured in the High School Musical Series
# Inside the Battle to Save the Golden Globes, as Publicists Eat Their Own and NBC Waits (EXCLUSIVE)
# Alec Baldwin announces Woody Allen interview: 'I have ZERO INTEREST in anyone’s judgments'
# Christian Bale: I Would Play Batman Again If Christopher Nolan Directs
# Carol Burnett to Guest Star on ‘Better Call Saul’ Final Season
# John Oliver calls out Democrats for not doing more to stop Roe from being overturned
# Kanye West emerges from 'hiatus' with surprise, Kardashian-referencing speech at BET Awards
# Givēon Performs “Lie Again” At 2022 BET Awards Following Mic Mishap
# Silk Sonic, Kendrick Lamar & More Record-Setters at 2022 BET Awards
# Janelle Monáe, Taraji P. Henson, Jazmine Sullivan speak out during politically charged BET Awards: 'F*** you, Supreme Court'
# 'Full House' star Jodie Sweetin shoved by police during protest, says she will 'continue fighting': More celebs react
# Jack Harlow Delivers “First Class” Performance With Brandy And Lil Wayne At 2022 BET Awards
# BET Awards 2022: See the full list of winners
# Dave Grohl Joins Paul McCartney at Glastonbury in First Performance Since Taylor Hawkins' Death
# Jack Harlow Wears Lil Nas X T-Shirt to BET Awards to Protest Snub
# Jodie Sweetin speaks out after being pushed by police at abortion rights protest: 'Our activism will continue'
# Matthew McConaughey Responds to President Biden Signing Gun Control Bill: 'Step in the Right Direction'
# Pink tells her fans who support the Supreme Court's decision to overturn Roe v. Wade to 'never f***ing listen to my music again'
# Nicole Kidman shares rare wedding photo as she celebrates 16 years of marriage to Keith Urban
# Green Day's Billie Joe Armstrong tells fans he's 'renouncing' his U.S. citizenship over Supreme Court ruling
# Lily Anne Harrison Is Pregnant, Expecting First Baby with Peter Facinelli: 'Not a Burrito Belly'
# Cam Ayala Takes Fans Inside Recovery as He Practices Walking After Leg Amputation: 'CAMputee'
# Susan Lucci Honors 'Larger-Than-Life' Late Husband Helmut Huber with Heartfelt Speech at Daytime Emmys
# Box Office: ‘Elvis’ and ‘Top Gun: Maverick’ Battle for No. 1 With $30.5 Million Each
# Bill Cosby to have a party to mark 1st anniversary of prison release
# 'Have you ever killed a man?' Kid reporters shock 'Minions' star Steve Carell with questions testing his evilness
# See the 'Thor: Love and Thunder' cast unbox merch from the latest Marvel blockbuster (exclusive)
# ‘Jeopardy!’ fans can’t even after contestant confuses Public Enemy with Marky Mark and the Funky Bunch
# Machine Gun Kelly explains self-sustained bloody head injury at concert: 'I didn’t have a fork'
# {2: 120, 1: 109}
# Dataframe holds 229 rows.
# X_train: 183
# X_test: 46
# Performing grid search...
# parameters:
# {'clf__max_iter': (20,),
#  'clf__penalty': ('l2', 'elasticnet'),
#  'vect__max_df': (0.5, 0.75, 1.0),
#  'vect__ngram_range': ((1, 1), (1, 2))}
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# done in 3.537s
#
# 	clf__max_iter: 20
# 	clf__penalty: 'l2'
# 	vect__max_df: 0.5
# 	vect__ngram_range: (1, 1)
# For Sentence:  Elizabeth Olsen Confirms She and Robbie Arnett 'Eloped' and 'Had a Wedding at Another Time' prediction was:  Entertainment
# For Sentence:  Hilarie Burton shares story of abortion after pregnancy loss: 'I only have my daughter because of my abortion' prediction was:  Entertainment
# For Sentence:  AT&T Makes BofA List of Potential Reshoring Beneficiaries prediction was:  Entertainment
# For Sentence:  2 “Strong Buy” Dividend Stocks With at Least 7% Dividend Yield prediction was:  Finance
# For Sentence:  'Have you ever killed a man?' Kid reporters shock 'Minions' star Steve Carell with questions testing his evilness prediction was:  Entertainment
# For Sentence:  Machine Gun Kelly Gives New Meaning to ‘My Bloody Valentine’ by Smashing Champagne Glass in His Face prediction was:  Entertainment
# For Sentence:  You're More Likely to Have Guaranteed Retirement Income If You Do This prediction was:  Entertainment
# For Sentence:  Two Stocks To Watch As The Oil Industry Battles A Water Crisis prediction was:  Finance
# For Sentence:  Here's How These Maps Will Change Your Perspective prediction was:  Finance
# For Sentence:  This veteran money manager has seen it all. And these 19 dividend stocks pass his rigorous quality screen right now. prediction was:  Finance
# For Sentence:  Chip Stocks Are in for Trouble, Analyst Says. 4 Stocks Get Downgrades. prediction was:  Finance
# For Sentence:  Bitcoin’s Next Headwind: Struggling Crypto Miners prediction was:  Finance
# For Sentence:  ‘Jeopardy!’ fans can’t even after contestant confuses Public Enemy with Marky Mark and the Funky Bunch prediction was:  Entertainment
# For Sentence:  Dow futures down over 300 points as losing first half closes and Fed’s favorite inflation gauge looms prediction was:  Finance
# For Sentence:  Jack Harlow Delivers “First Class” Performance With Brandy And Lil Wayne At 2022 BET Awards prediction was:  Entertainment
# For Sentence:  Ad
# Her Annual Salary Has the Internet Buzzing prediction was:  Entertainment
# For Sentence:  Influencers with Andy Serwer: Costis Maglaras prediction was:  Entertainment
# For Sentence:  Janelle Monáe, Taraji P. Henson, Jazmine Sullivan speak out during politically charged BET Awards: 'F*** you, Supreme Court' prediction was:  Entertainment
# For Sentence:  'Have you ever killed a man?' Kid reporters shock 'Minions' star Steve Carell with questions testing his evilness prediction was:  Entertainment
# For Sentence:  Dow Jones Futures Sell Off After Key Inflation Report prediction was:  Finance
# For Sentence:  Ron Perlman Marries Fiancée Allison Dunbar in Italy: 'Spring Has Indeed Sprung' prediction was:  Finance
# For Sentence:  Ad
# This Is What Historical Figures Really Looked Like prediction was:  Entertainment
# For Sentence:  Jason Kander Was a Rising Star in the Democratic Party. Then He Went on Suicide Watch prediction was:  Entertainment
# For Sentence:  R. Kelly to be sentenced in sex-trafficking case: The Refresh prediction was:  Entertainment
# For Sentence:  RBC Says These 2 Dividend Stocks Have Strong Growth Potential prediction was:  Finance
# For Sentence:  How can I 'quiet' my portfolio? Here are 3 top dividend stocks for stable cash return and inflation protection — one of them even offers an incredible 14.9% yield prediction was:  Finance
# For Sentence:  Christian Bale still hasn't watched Robert Pattinson in 'The Batman,' but thinks he's 'absolutely magnificent' prediction was:  Entertainment
# For Sentence:  Laura Prepon reflects on having a life-saving abortion: 'At the time, I had the choice' prediction was:  Entertainment
# For Sentence:  Why Congress’ new retirement reforms aren’t all they’re cracked up to be prediction was:  Finance
# For Sentence:  Global response to climate will 'change the world over the next 75 years': Costis Maglaras prediction was:  Entertainment
# For Sentence:  Selena Gomez Calls on Men to ‘Stand Up’ & ‘Speak Against’ Supreme Court’s Overturning of Roe v. Wade prediction was:  Entertainment
# For Sentence:  The It List: Rare female perspective on the oligarch world featured in Paramount+ doc, 'Stranger Things' Season 4 feature-length finale episodes hit Netflix and all the best in pop culture the week of June 27, 2022 prediction was:  Entertainment
# For Sentence:  Wrap Foil Around Doorknobs When Alone, Here's Why prediction was:  Entertainment
# For Sentence:  JPMorgan Says Crypto’s Deleveraging Cycle Won’t Last Much Longer prediction was:  Finance
# For Sentence:  ‘True Detective’ Season 4 at HBO Casts Kali Reis in Lead Role Opposite Jodie Foster prediction was:  Entertainment
# For Sentence:  Woody Allen expects his 50th film to be his last: 'The thrill is gone' prediction was:  Entertainment
# For Sentence:  Ashlee Simpson Ross' Son Bronx, 13, Looks All Grown Up in 'London Dinner Date' Photo with Mom prediction was:  Entertainment
# For Sentence:  Looking for dealmaking opportunities for startups? prediction was:  Finance
# For Sentence:  Chip Design Firms Upgraded As Chipmakers Downgraded prediction was:  Finance
# For Sentence:  Palace Probe Following Meghan Markle Bullying Claims Is 'Complete,' Says Royal Aide prediction was:  Finance
# For Sentence:  Lily Anne Harrison Is Pregnant, Expecting First Baby with Peter Facinelli: 'Not a Burrito Belly' prediction was:  Entertainment
# For Sentence:  Vanessa Hudgens Visits the Iconic School Featured in the High School Musical Series prediction was:  Entertainment
# For Sentence:  Bitcoin fights to stay above $20,000 as Saylor buys another $10 million worth prediction was:  Finance
# For Sentence:  EXCLUSIVE: Lachlan Watson to Star As Glen/Glenda In 'Chucky' Season 2 prediction was:  Entertainment
# For Sentence:  Ciara on singing with her kids, moving her family to Denver and her son's reaction to her Sports Illustrated Swimsuit cover prediction was:  Entertainment
# For Sentence:  See the 'Thor: Love and Thunder' cast unbox merch from the latest Marvel blockbuster (exclusive) prediction was:  Entertainment
# grid_search.predict(Which is the fastest bike?):  [1]
# The accuracy of model on test set is: 0.8478260869565217
# C:\Users\97252\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:922: UserWarning: One or more of the test scores are non-finite: [0.80855856 0.7975976  0.80855856 0.7975976  0.80855856 0.7975976
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# The Precision: 0.8823529411764706
# The Recall: 0.75
# tgbfg
